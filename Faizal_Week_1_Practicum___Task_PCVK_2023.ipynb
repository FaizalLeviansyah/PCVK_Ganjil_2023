# %% [markdown]
# <a href="https://colab.research.google.com/github/FaizalLeviansyah/PCVK_Ganjil_2023/blob/main/Faizal_Week_1_Practicum___Task_PCVK_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
import cv2
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari berbagai img
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

for url in urls :
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Questions :
# 1. Explain why in this practicum module the execution of Python code is done using Google Colab?
#
# -> Answer :
# Google Colab is utilized in this practicum module for several key purposes: Machine Learning Model Training, Large Dataset Analysis, Data Visualization, also Google Colab is a valuable and accessible tool for running Python code and completing a range of data science tasks. It is known for its cost-effectiveness, ease of use, and collaborative features, making it a suitable choice for various data-related activities.
#
# 2. Explain the use of each library in the eighth step practicum? Do all these libraries have to be used in this practical session?
# -> Answer :
#
# - numpy = This library provides high-performance numerical computation in Python. It is used for a variety of tasks in this practicum, including loading and processing images, computing features, and training machine learning models.
#
# - pandas = This library provides high-performance, easy-to-use data structures and data analysis tools for Python. It is used in this practicum for loading and processing the dataset of images.
#
# - cv2 = This library provides a Python interface to the OpenCV library, which is a popular computer vision library. It is used in this practicum for loading, displaying, and processing images.
#
# - google.colab.patches = This library provides a function called cv2_imshow() that can be used to display images in Google Colab. It is used in this practicum to display the images that are loaded and processed.
#
# - skimage = This library provides a variety of image processing and analysis tools for Python. It is used in this practicum for resizing images and computing features.
#
# - transform = This module in skimage provides functions for geometric transformations of images. It is used in this practicum for rotating and flipping images.
#
# - PIL = This library provides a Python interface to the Pillow library, which is a popular image processing library. It is used in this practicum for saving images.
#
# - matplotlib.pylab = This library provides a MATLAB-like interface to matplotlib, which is a popular plotting library. It is used in this practicum for plotting the results of the machine learning experiments.

# %% [markdown]
# 3. In the 8th step of the experiment there is a snippet of program code as follows:

# %%
image = cv.resize(image, (0,0), fx=0.5, fy=0.5)

# %% [markdown]
# What is the use of the program code ? and what is the effect if it is not done?
#
# -> Answer :
# - it's code snippet is used to resize the image to half its original size.
#
# - If the code snippet is not done, the image will not be resized.
#
# - Not resizing the image may have negative effects on the machine learning model, such as making it less able to learn the features of the image effectively and less generalizable to new data.
#
#
# 4. Take a look at the following program code snippet :

# %%
for y in range (lebar) :
  image_3[int((tinggi)/2),y] = [255,255,255]

# %% [markdown]
# What is the use of code [255,255,255] ? explain ?
#
# -> Answer :
# The code [255,255,255] represents the color white in RGB color space. In the snippet of program code for y in range (lebar) : image_3[int((tinggi)/2),y] = [255,255,255], the code [255,255,255] is used to set the pixel at the row specified by int((tinggi)/2) and column specified by y to white.
#
# 5. Explain the relationship between pixels and high or low image resolution!
#
# -> Answer :
# - Pixels are the individual dots that make up an image. The more pixels an image has, the higher its resolution will be.
#
# - High-resolution images have a lot of pixels, which means that they are very detailed. They can be printed at large sizes without losing quality.
#
# - Low-resolution images have fewer pixels, which means that they are not as detailed. They can be printed at smaller sizes, but they may look blurry or pixelated when enlarged.
#
#   In general, high-resolution images are preferred for printing and viewing on large screens. Low-resolution images are typically used for online viewing or for sending images via email.

# %% [markdown]
# TASK 1 :
# 1. Do the practical steps above
#
# -> Answer : Done in above.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Create vertical lines
for x in range(lebar):
    image_3[int((tinggi)/2),y] = [255, 255, 255]  # Red vertical lines

# Create diagonal lines
for i in range(min(lebar, tinggi)):
    image_3[i, i] = [255, 255, 255]  # Blue diagonal lines

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 2. Create diagonal lines & Vertical Lines in the output images
# -> Answer : Done in above.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Get the dimensions of the image
tinggi, lebar, _ = image.shape

# Create a copy of the image to work with
image_2 = image.copy()

# Create a copy of the image for adding vertical lines
image_3 = image.copy()

# Define the x-coordinates where you want vertical lines
vertical_line_x = [lebar // 4, lebar // 2, 3 * lebar // 4]

to gave vertical line
#[lebar // 4, lebar // 2, 3 * lebar // 4]

# Set the color of vertical lines at the specified x-coordinates
for x in vertical_line_x:
    image_3[:, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 3. Draw the horizontal white lines in the middle of image with certain length
# -> Answer : Done in above.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Get the dimensions of the image
tinggi, lebar, _ = image.shape

# Create a copy of the image
image_2 = image.copy()

# Define the length and thickness of the horizontal white line
line_length = 100  # Adjust this value as needed
line_thickness = 2  # Adjust this value as needed

# Calculate the starting and ending points for the line
start_x = (lebar - line_length) // 2
end_x = start_x + line_length

# Create a white line in the middle of the image
image_2[int(tinggi / 2) - line_thickness // 2:int(tinggi / 2) + line_thickness // 2, start_x:end_x] = [255, 255, 255]

# Concatenate the original and modified images horizontally
final_frame = np.hstack((image, image_2))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 4. Draw a box from a collection of white pixel in certain area in the image
# -> Answer : Done in above.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Assuming you have already defined 'lebar' and 'tinggi'
lebar = image.shape[1]
tinggi = image.shape[0]

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Define the coordinates for the top-left and bottom-right corners of the box
box_top_left = (100, 100)  # Example coordinates (adjust as needed)
box_bottom_right = (200, 200)  # Example coordinates (adjust as needed)

# Create a white box in the specified area
image_3[box_top_left[1]:box_bottom_right[1], box_top_left[0]:box_bottom_right[0]] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
